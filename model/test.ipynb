# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta

samples = np.random.beta(0.9, 0.9, 1000)

 # Generate n points between 0 and 1
points = np.linspace(0.1, 0.9, 1000)
    
    # Calculate the probability mass for each point using the beta distribution
probabilities = beta.pdf(np.linspace(0.1, 0.9, 1000), 0.9, 0.9)
    
    # Normalize probabilities to sum to 1
probabilities /= np.sum(probabilities)
plt.hist(samples)
# Out:
# (array([134., 102.,  92.,  90.,  96.,  88.,  74.,  98., 105., 121.]),
#  array([5.36462889e-04, 1.00438825e-01, 2.00341186e-01, 3.00243548e-01,
#         4.00145910e-01, 5.00048272e-01, 5.99950633e-01, 6.99852995e-01,
#         7.99755357e-01, 8.99657719e-01, 9.99560080e-01]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
# Create a figure and subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot the first graph
axs[0].plot([1,2,3,4,3,2,1])
minDiv = min([1,2,3,4,3,2,1])
axs[0].set_title("Postprocessed")
axs[0].set_xlabel('Training Iteration')
axs[0].set_ylabel('Wasserstein Distance')
axs[0].grid(axis='y')

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
arrowprops = dict(arrowstyle="->", connectionstyle="angle,angleA=0,angleB=60")
kw = dict(xycoords='data', textcoords="axes fraction", arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")

# Plot the second graph
axs[1].plot([1,2,3,4,3,2,1])
minDiv = min([1,2,3,4,3,2,1])
axs[1].set_title("Preprocessed")
axs[1].set_xlabel('Training Iteration')
axs[1].set_ylabel('Wasserstein Distance')
axs[1].grid(axis='y')


plt.tight_layout()
plt.show()
